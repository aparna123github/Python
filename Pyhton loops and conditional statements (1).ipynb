# %% [markdown]
# # Conditional statements

# %% [raw]
# Equals: a == b
# Not Equals: a != b
# Less than: a < b
# Less than or equal to: a <= b
# Greater than: a > b
# Greater than or equal to: a >= b

# %% [markdown]
# ### IF STATEMENT

# %%
a = 33
b = 200
if b > a:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
x = 10

if x > 5:
    print("x is greater than 5")
# Out:
# x is greater than 5

# %%
a = 'girl'
b = 'boy'

if a == 'girl':
    print('girl found')
# Out:
# girl found

# %%
age = 20
if age >= 18:
  print("You are an adult")
  print("You can vote")
  print("You have full legal rights")
# Out:
# You are an adult
# You can vote
# You have full legal rights

# %%
a = 5
b = 10

print(a == b)   # False
print(a < b)    # True
# Out:
# False
# True

# %% [markdown]
# ### ELSE IF STATEMENT

# %%
age = 16

if age >= 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Minor

# %%
a = 33
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
# Out:
# a and b are equal

# %%
x = 10

if x == 50:
    print('NE')
if x == 10:
    print("equal")
if x == 38:
    print('NE')
# Out:
# equal

# %%
score = 75

if score >= 90:
  print("Grade: A")
elif score >= 80:
  print("Grade: B")
elif score >= 70:
  print("Grade: C")
elif score >= 60:
  print("Grade: D")
# Out:
# Grade: C

# %% [markdown]
# ### Logical operators

# %%
#AND OPERATOR - both condition should be true
age = 25

if age >= 18 and age <= 60:
    print("Eligible")
# Out:
# Eligible

# %%
#OR OPERATOR - one condition can be true
day = "Sunday"

if day == "Saturday" or day == "Sunday":
    print("Holiday")
# Out:
# Holiday

# %%
#NOT CONDITION - reverses condition
is_logged_in = False

if not is_logged_in:
    print("Please login")
# Out:
# Please login

# %%
# day of the week checker
day = 3

if day == 1:
  print("Monday")
elif day == 2:
  print("Tuesday")
elif day == 3:
  print("Wednesday")
elif day == 4:
  print("Thursday")
elif day == 5:
  print("Friday")
elif day == 6:
  print("Saturday")
elif day == 7:
  print("Sunday")
# Out:
# Wednesday

# %% [markdown]
# ### ELSE CONDITION

# %%
#when if condition evaluates to false, we use this
x = 3

if x > 0:
    print("Positive")
else:
    print("Not positive")
# Out:
# Positive

# %%
#EVEN OR ODD
num = 7

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %%
#AGE CHECK
age = 18

if age > 18:
    print("Above 18")
else:
    print("18 or below")
# Out:
# 18 or below

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
else:
  print("b is not greater than a")
# Out:
# b is not greater than a

# %% [markdown]
# ### NESTED IF

# %%
#USED WHEN ONE IF IS DEPENDENT ON OTHER
num = 8

if num > 0:
    if num % 2 == 0:
        print("Positive and even")
# Out:
# Positive and even

# %%
#LOGIN CHECK
username = "admin"
password = "1234"

if username == "admin":
    if password == "1234":
        print("Login successful")
    else:
        print("Wrong password")
else:
    print("Wrong username")
# Out:
# Login successful

# %%
username = "admin"
password = "1234"

if username == "admin":
    if password == "1294":
        print("Login successful")
    else:
        print("Wrong password")
else:
    print("Wrong username")
# Out:
# Wrong password

# %%
#MARKS GRADING
marks = 72

if marks >= 40:
    if marks >= 75:
        print("Distinction")
    else:
        print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
numbers = [1, 2, 3]

if numbers:
    if 5 in numbers:
        print("5 found")
    else:
        print("5 not found")
else:
    print("List is empty")
# Out:
# 5 not found

# %% [markdown]
# ### Pass statement

# %%
a = 33
b = 200

if b > a:
  pass

# %%
age = 16

if age < 14:
  pass # TODO: Add underage logic later
else:
  print("Access granted")
# Out:
# Access granted

# %%
score = 85

if score > 90:
  pass # This is excellent
print("Score processed")
# Out:
# Score processed

# %% [markdown]
# ### FOR LOOPS

# %% [raw]
# for loop → when you know how many times
#
# while loop → when you don’t know how many times

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
for x in "banana":
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  if x == "banana":
    continue
  print(x)
# Out:
# apple
# cherry

# %%
for x in range(2, 30, 3):
  print(x)
# Out:
# 2
# 5
# 8
# 11
# 14
# 17
# 20
# 23
# 26
# 29

# %%
for x in range(6):
  print(x)
else:
  print("Finally finished!")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# Finally finished!

# %%
#print even numbers
for i in range(1, 11):
    if i % 2 == 0:
        print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
#loop through a list
colors = ["red", "green", "blue"]

for color in colors:
    print(color)
# Out:
# red
# green
# blue

# %%
#sum of numberes in a list
numbers = [10, 20, 30]
total = 0

for n in numbers:
    total += n

print(total)
# Out:
# 60

# %% [markdown]
# ### While loop

# %%
#set of statements as long as it is true
i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#print from 1 to 5
i = 1

while i <= 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 2

while i <= 10:
    print(i)
    i +=2
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
# reverse
i = 5

while i >= 1:
    print(i)
    i -= 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
#infinte loop
#while True:
 #   print("Hello")

# %%
num = int(input("Enter a number: "))
total = 0

while num > 0:
    digit = num % 10
    total += digit
    num //= 10

print("Sum of digits:", total)
# Out:
# Enter a number:  2344
# Sum of digits: 13
