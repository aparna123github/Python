# %% [markdown]
# ### copy the elements

# %%
a=[1,2,3,4,5]
b=a.copy()
b
# Out:
# [1, 2, 3, 4, 5]

# %%
import copy
a=[[1,2],[3,4],[23,43]]   
b=copy.deepcopy(a)     #for nested list
b
# Out:
# [[1, 2], [3, 4], [23, 43]]

# %% [markdown]
# ### area of rectangle

# %%
length = 22
breadth = 43
area of rectangle = l*b
print(area of rectangle)
# Out:
# 946

# %% [markdown]
# ### area of circle

# %%
r= 22
pie=3.14
area= pie*r*r
print(area)
# Out:
# 1519.76

# %% [markdown]
# ### sum of the list

# %%
a = [1,2,3,4,5,6,7,8,9,0]
print(sum(a))
# Out:
# 45

# %%
a=[22,33,22,55,66]
b=[45,45,5,2,1,]
total_sum=sum (a)  #can't take two arg here*
total_sum
# Out:
# 198

# %%
a=[198,393,392]
res=sum (a)
res
# Out:
# 983

# %% [markdown]
# ### multiply all no. in the list

# %%
import math
a= [2,4,2,1,3]
product= math.prod(a)  #math library provides prod function for multi
product
# Out:
# 48

# %%
a=[2,3,4,1]
product= (2*3*4*1)
product
# Out:
# 24

# %% [markdown]
# ### finding max and min in a list

# %%
a = [10, 24, 76, 23, 12]
res = max(a)
print(res)
res1 =min(a)
print(res1)
# Out:
# 76
# 10

# %% [markdown]
# ### largest and smallest no. in the listt

# %%
a = [32,4,522,74,254,476,82]
print('largest:', max(a))
print('smallest:',min(a))
# Out:
# largest: 522
# smallest: 4

# %% [markdown]
# ### count the no. of elements

# %%
a = [2,3,4,5,3,2,3,4,5,3,4,4,2]
print ("count of 4;",(4))
# Out:
# count of 4; 4

# %% [markdown]
# ### reverse a list without using reverse

# %%
a = [22,33,21,76,113]
reverse = a [::-1]
print(reverse)
# Out:
# [113, 76, 21, 33, 22]

# %% [markdown]
# ### check whether a list is empty

# %%
list=[]
if not list:
    print('list is empty')
else:
    print('list is not empty')
# Out:
# list is empty

# %% [markdown]
# ### print elements at even indexes

# %%
numbers = [10, 20, 30, 40, 50, 60]
print(numbers[::2])
# Out:
# [10, 30, 50]

# %% [markdown]
# ### print no. at odd index

# %%
numbers = [32,3,2,3,31,123]
print(numbers[1::2])
# Out:
# [3, 3, 123]

# %% [markdown]
# ### find the sum and average

# %%
a = [12,21,12,14]
total = sum(a)
average = total/len(a)
print(total)
print(average)
# Out:
# 59
# 14.75

# %% [markdown]
# ### find the squares of the element

# %%
a = [1, 2, 3, 4]
square = [n*n for n in a]
print(square)
# Out:
# [1, 4, 9, 16]

# %% [markdown]
# ### check if the list is palindrome

# %%
a = [1, 2, 3, 2, 1]

if a == a[::-1]:
    print("Palindrome")     # same form both the sides
else:
    print("Not Palindrome")
# Out:
# Palindrome

# %% [markdown]
# ### merge two lists

# %%
a = [1, 2, 3]
b = [4, 5, 6]

merged = a + b
print(merged)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### find the second largest element

# %%
numbers = [10, 20, 5, 30]
numbers = list(set(numbers))  # remove duplicates
numbers.sort()                # sort in ascending order
print(numbers[-2])            # second largest element
