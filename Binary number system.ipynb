# %% [raw]
# PYTHON NO.SYSTEM
# binary -      0 to 1  (0b)
# octal   -     0 to 6  (0o)
# decimal-     0 to 9   (0x)
# hexadecimal - 0 to f (a -10, b-12, c-13..........)

# %%
25
# Out:
# 25

# %%
bin(25) #no. to binary no.
# Out:
# '0b11001'

# %%
int(0b11001) #binary no. to binary
# Out:
# 25

# %%
oct(25)
# Out:
# '0o31'

# %%
hex(1)
# Out:
# '0x1'

# %%
hex(8)
# Out:
# '0x8'

# %%
hex(10)  #10 referring to a
# Out:
# '0xa'

# %% [markdown]
# #### how to swap two varibles in python

# %%
a= 5
b= 6

# %%
temp = a
a = b
b = temp
print(a)
print(b)
# Out:
# 5
# 6

# %%
a2 = 5 
b2 = 6
a2 = a2 + b2
b2 = a2 - b2
a2 = a2 - b2
print(a2)
print(b2)
# Out:
# 6
# 5

# %%
a1 = 7
b1 = 8
a1, b1 = b1, a1
print(a1)
print(b1)
# Out:
# 8
# 7

# %% [markdown]
# ## Bitwise operator

# %% [raw]
# complement
# and &
# or |
# xor (xclusive or)^
# left shift <<
# right shift >>

# %%
#complement operator,negative values will be obtained
~ 12
# Out:
# -13

# %%
~ 45 #negative value,with +1
# Out:
# -46

# %%
~1
# Out:
# -2

# %%
print(bin(12))
print(bin(13))
# Out:
# 0b1100
# 0b1101

# %%
12 & 13
# Out:
# 12

# %%
# and operator

# %%
14 & 15
# Out:
# 14

# %%
# or operator

# %%
12 | 13
# Out:
# 13

# %%
45 |46
# Out:
# 47

# %%
22 | 23
# Out:
# 23

# %%
# xor operatr

# %%
0 ^ 0
# Out:
# 0

# %%
0 ^ 1
# Out:
# 1

# %%
1 ^ 0
# Out:
# 1

# %%
1 ^ 1
# Out:
# 0

# %%
12 ^  13
# Out:
# 1

# %%
# left shift,gain the bits

# %%
12 << 2
# Out:
# 48

# %%
# right shift, loose the bits

# %%
13 >> 2
# Out:
# 3

# %%
24 >> 2
# Out:
# 6

# %% [markdown]
# ### Binary arithmetic in Python

# %%
a = 0b1010   # 10
b = 0b0101   # 5

print(a + b)        # 15
print(bin(a + b))   # '0b1111'
# Out:
# 15
# 0b1111
