# %% [markdown]
# ## FUNCTIONS
# ### A function is a block of code which only runs when it is called.

# %%
FUNCTIONS ARE OF TWO TYPES:
FORMAL ARG
ACTUAL ARG
IN ACTUAL ARG THERE ARE 4 TYPES:
POSITIONAL  ARG
KEYWORD     ""
DEFAULT     ""
VARIABLE    ""

# %%
def hello():
    print("good morning michael")
    print("how are you")

# %%
def hello():
    print("good morning michael")
    print("how are you")
hello()
#it will only print when uh will call the function
#with corrct identation*
# Out:
# good morning michael
# how are you

# %%
def hello():
    print("good morning michael")
    print("how are you")
hello()

hello()

hello()
# Out:
# good morning michael
# how are you
# good morning michael
# how are you
# good morning michael
# how are you

# %%
def hello():
    print("good morning michael")
    print("how are you")
hello('everyone')
#there's no positional arg given to the function
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       2     print("good morning michael")
#       3     print("how are you")
# ----> 4 hello('everyone')
#
# TypeError: hello() takes 0 positional arguments but 1 was given

# %%
def greet(name):
    print("Hello", name)
greet("you")
# Out:
# Hello you

# %%
def add(x, y):
    c=x+y
    print(c) 
    
add(5, 6)
# Out:
# 11

# %%
def add(x, y):
    c=x+y
    print(c) 
    
add(5, 6,7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 5
#       2     c=x+y
#       3     print(c)
# ----> 5 add(5, 6,7)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
THE POSITIONAL ARG SHOULD BE EQUAL TO THE FORMAL ARG TO AVOID THIS ERROR
THEREFORE , NOW WE WILL INC THE ARG AS WELL

# %%
def add(x, y,Z):
    c=x+y
    print(c) 
    
add(5, 6,7)
# Out:
# 11

# %%
def greet(): 
    print('hello')
    print('good morning')

greet()

def add(x, y):
    c=x+y
    return c
    
add(5, 6)
# Out:
# hello
# good morning
# 11

# %%
#correct way of writing the code
def greet(): 
    print('hello')
    print('good morning')


def add(x, y):
    c=x+y
    return c
greet()
add(5, 6)
# Out:
# hello
# good morning
# 11

# %%
def add_sub(x, y): # what if i want to return 2 values add_sub & i want to return 2 values & function can accept multiple value 
    c= x+y
    d= x-y
    return c, d 
    
result = add_sub(4,5)

print(result)
print(type(result))
# Out:
# (9, -1)
# <class 'tuple'>

# %%
def add_sub(x, y): 
    c= x+y
    d= x-y
    return c, d 
    
result,result1 = add_sub(4,5)

print(result)
print(result1)
# to print the values seprately we have to assign diff names to the variable
# Out:
# 9
# -1

# %%
def add_sub_mul(x, y):  
    c= x+y
    d= x-y
    e = x*y
    return c, d, e

add_sub_mul(5, 2)
# Out:
# (7, 3, 10)

# %%
def add_sub_mul(x, y): 
    c= x+y
    d= x-y
    e = x*y
    return c, d, e

r,r1,r2 = add_sub_mul(5, 2)
print(r)
print(r1)
print(r2)
# Out:
# 7
# 3
# 10

# %%
# function with arg has these twao types

# %%
def add(a,b): # a, b -- FORMAL ARGUMENT 
    c = a+b
    return c
add(5,6) # 5 , 6 --- ACTUAL ARGUMENT

# %%
def my_function(fname):
  print(fname +  " everyone")

my_function("hi")
my_function("hello")
my_function("hey")
# Out:
# hi everyone
# hello everyone
# hey everyone

# %%
def students(girls):
    print(girls + " good")
students("she's not")
students("she's")
# Out:
# she's not good
# she's good

# %% [markdown]
# ### Positonal arguments
# ### alwasy sees the position

# %%
def person(name, age):
    print(name)
    print(age)
person ('nit',22)
# Out:
# nit
# 22

# %%
def person(name, age):
    print(name)
    print(age)
person (22,'nit')
# Out:
# 22
# nit

# %%
SO TO SOLVE THIS PROBLEM OF POSITONAL ARG WE INTRODUCED THE KEYWORD ARG

# %% [markdown]
# ### Keyword arguments
# ### can specify arguments by name.

# %%
def student(name, age):
    print(name, age)
student (age = 22, name ='palak')
# order would not matter while calling the function
# Out:
# palak 22

# %%
def student (name, age):
    print(name)
    print(age)
student(age = 22, name = 'nit')
# Out:
# nit
# 22

# %%
def person(name, age, phone):
    print(name)
    print(age+1)
    print(phone)
    
person(age = 22, name = 'nit', phone = 789)
# Out:
# nit
# 23
# 789

# %% [markdown]
# ### By default arg
# ### args are defined in formal arg

# %%
def person (name, age = 18):
    
     print(name)
     print(age)
person('nit')
# Out:
# nit
# 18

# %%
def person (name, age = 18):
    
     print(name)
     print(age)
person('nit', 17)
# Out:
# nit
# 17

# %%
def person (name, age = 18):
    
     print(name)
     print(age)
person(17,'nit')
# Out:
# 17
# nit

# %% [markdown]
# ### Variable length arg
# ### it is used when we dont know how many args will be passed
# ### also known as arbitary keyword arg

# %%
def sum(a, b):
    c = a+b
    return c
    
sum(5,6)
# Out:
# 11

# %%
def sum(a, b): 
    c = a+b
    return c
    
sum(5, 6, 7, 8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 5
#       2     c = a+b
#       3     return c
# ----> 5 sum(5, 6, 7, 8)
#
# TypeError: sum() takes 2 positional arguments but 4 were given

# %%
def sum(a, *b): 
    c = a+b
    return c
    
sum(5, 6, 7, 8)  
# *b cahnges the error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 5
#       2     c = a+b
#       3     return c
# ----> 5 sum(5, 6, 7, 8)
#
# Cell In[63], line 2, in sum(a, *b)
#       1 def sum(a, *b):
# ----> 2     c = a+b
#       3     return c
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
def sum(a, *b): # 1st argument is fixed but for 2nd argument
    #c = a+b
    print(a)
    print(type(a))
    
    print(b)
    print(type(b))

sum(5,6,7,8) 
# 6,7,8 is taken as tuple
# Out:
# 5
# <class 'int'>
# (6, 7, 8)
# <class 'tuple'>

# %% [markdown]
# #### a = 5
#
# #### b = (6, 7, 8) ← tuple

# %% [markdown]
# ### *args is treated as a tuple

# %% [markdown]
# ### we use for loops for all the sequences like -- list tuple set dict

# %%
def sum(a, *b): # 1st argument is fixed & we fetch each value from the tuple & we can add them. 
    c = a  
    
    for i in b:
        c = c + i 
    print(c)
        
sum(5,6,7,8)
# Out:
# 26

# %%
def sum(a, *b): 
    c = 0  
    
    for i in b:
        c = c + i 
    print(c)
        
sum(5,6,7,8)
# Out:
# 21

# %%
def sum(a, *b):  
    c = a  
    
    for i in b:
        c = c + i 
    print(c)
        
sum(5,6,7,8,9,10,-1,-2,-3, 100, )
# Out:
# 139

# %%
# function with no arg
def cs():
      return("hello")
cs()
# Out:
# 'hello'

# %%
# function with one arg
def square(num):
    return num * num

print(square(4))
# Out:
# 16

# %%
# function with multiple arg
def student(a,b,c,d):
    return(a + b +c +d)
student(1,2,3,4)
# Out:
# 10

# %%
# function with default arg
def student (name  = 'aparna', college = 'nit'):
     return f" hello, {name},welcome to {college}"
print(student())
# Out:
#  hello, aparna,welcome to nit

# %%
def mobile( name = 'oppo', quality = 'good'):
    return f" hie {name},your qualtiy is {quality}"

print(mobile())
# Out:
#  hie oppo,your qualtiy is good

# %%
def mobile( name = 'motorola', quality = 'good'):
    return f" hie {name},your qualtiy is {quality}"

print(mobile())
# Out:
#  hie motorola,your qualtiy is good

# %%
# below code is known as passing our own value

# %%
def mobile( name = 'motorola', quality = 'good'):
    return f" hie {name},your qualtiy is {quality}"

print(mobile('samsung', 'practical'))
# Out:
#  hie samsung,your qualtiy is practical

# %%
print(mobile(quality="best", name="Apple"))
# order will not matter here as names are used
# Out:
#  hie Apple,your qualtiy is best

# %%
# function with keyword args
def student(name, age, city):
    print(f"Name: {name}, Age: {age}, City: {city}")

student(age=20, name="Aparna", city="Delhi")
# Out:
# Name: Aparna, Age: 20, City: Delhi
