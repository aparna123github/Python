# %% [markdown]
# ## 10  jan

# %%
num1 = 20
num2 = 30
add = num1 + num2
print(f"The addition of {num1} and {num2} is {add}")
# Out:
# The addition of 20 and 30 is 50

# %%
'nit' + 'nit' #addition of string is possible
# Out:
# 'nitnit'

# %%
'nit' * "nit" #multiplication is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 'nit' * "nit" #multiplication is not possible
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
5 * 'nit'   #string can be multiplled different times

# %%
5 * ' nit'  #for space

# %% [markdown]
# ### Numbers

# %%
>>> 2 +2

# %%
>>> 50 - 5.6

# %%
>>> tax = 12.5/100
>>> price = 1000
>>> print(price * tax)
>>> print(price + _)
>>> print(round(_, 2)

# %% [markdown]
# ### string vs raw string
# #### in raw string we read the path loaction in future

# %%
 print('applne' \n 'hello')

# %%
tax = 20 
price = 30
tax * price

# %%
tax + _ #699 + 20

# %%
round(15.5)

# %% [markdown]
# ### how to use help function

# %% [markdown]
#  ### functions that we are studying -- id()print()len()

# %%
print('doesn\'t')
# Out:
# doesn't

# %%
"doesn't"
# Out:
# "doesn't"

# %%
'doesn\'t'
# Out:
# "doesn't"

# %%
"yes they said;/n this"
# Out:
# 'yes they said;/n this'

# %%
'"yes\"  they said'
# Out:
# '"yes"  they said'

# %%
"doesn\'t"
# Out:
# "doesn't"

# %%
'doesnt'
# Out:
# 'doesnt'

# %%
'"yes,"they said.'
# Out:
# '"yes,"they said.'

# %%
'first line.\nsecond line.'
# Out:
# 'first line.\nsecond line.'

# %%
3 *'un'+'ium'
# Out:
# 'unununium'

# %%
'py''thon'
# Out:
# 'python'

# %%
print(' basic design principles'
          ' are very popular these days')
# Out:
#  basic design principles are very popular these days

# %%
"First line\nSecond line"
# Out:
# 'First line\nSecond line'

# %%
print("First line\nSecond line")
# Out:
# First line
# Second line

# %%
print(r"hello world " "names")
# Out:
# hello world names

# %% [markdown]
# ### indexing
# #### it will be used in pandas, machine learing,string
# #### indexing begins with 0

# %% [markdown]
# ## indexing

# %%
index = 'welcome'
index
print(index[0])
print(index[1])
print(index[2])
print(index[3])
print(index[4])
#print(index[100]) - string index out of range

# %%
index = 'welcome'
for i in index:
      print(i)

# %%
index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 index
#
# NameError: name 'index' is not defined

# %% [markdown]
# # 12 jan

# %%
index = 'welcome'
print(index)
# Out:
# welcome

# %% [markdown]
# ### package is collection of module
# ### module is collection of fucntion
# ### function is of two types inbuilt and user defined
# ### inbuilt
# ### print(),id(),len(),type()
# ### user def()
# ### alwas starts whith def()
# ### from dmart.clothing import jeans
# ### dmart-pkg
# ### clothing-module
# ### /jeans-function

# %%
index[:]
# Out:
# 'welcome'

# %%
index[10:0]  #null
# Out:
# ''

# %%
index[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 index[10]
#
# IndexError: string index out of range

# %%
index[:10]
# Out:
# 'welcome'

# %%
index[1282120:0]
# Out:
# ''

# %%
i1='nareshit'
i1
# Out:
# 'nareshit'

# %%
i1[2:-1]
# Out:
# 'reshi'

# %%
i1[::2] #step indexing
# Out:
# 'nrsi'

# %%
i1[::-1] #reverse slicing
# Out:
# 'tihseran'

# %%
i1[::-3]
# Out:
# 'tsa'

# %%
i1[0:6:2]
# Out:
# 'nrs'
